# %% [markdown]
# <a href="https://colab.research.google.com/github/abdus-git/NLP/blob/main/stop_word_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

try:
    stopwords.words('english')
    word_tokenize('test')
except LookupError:
    nltk.download('stopwords')
    nltk.download('punkt')
    try:
        nltk.data.find('tokenizers/punkt_tab/english/')
    except LookupError:
        nltk.download('punkt_tab')


def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    return " ".join(filtered_sentence)

document = "This is an example sentence, showing off the stop word removal."
filtered_document = remove_stopwords(document)
print(f"Original document: {document}")
print(f"Filtered document: {filtered_document}")
# Out:
# Original document: This is an example sentence, showing off the stop word removal.
# Filtered document: example sentence , showing stop word removal .
